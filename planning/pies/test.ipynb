# %%
import importlib
import dreamtree_walker
importlib.reload(dreamtree_walker)
from dreamtree_walker import ContentWalker

# Point it at your CSV folder
walker = ContentWalker('tables')

# %%
walker.stats()

# %%
walker.walk()

# %%
# See the landscape
walker.stats()           # counts by type, part, etc.
walker.outline()         # structural overview
walker.outline(part=1)   # just Part 1

# Walk sequentially
walker.show(1, 13)       # show sequences 1-13
walker.walk()            # interactive mode (Enter=next, q=quit, number=jump)

# Jump around
walker.goto(100)         # jump to sequence 100
walker.next(5)           # show next 5 from current position

# Find things
walker.find_tools()      # all 52 tool appearances
walker.find_prompts()    # all 204 prompts with types
walker.find_by_location(1, 1)        # everything in Module 1.1
walker.find_by_location(2, 3, 1)     # Exercise 2.3.1 specifically

# Search
walker.search("SOARED")
walker.search("ranking")
